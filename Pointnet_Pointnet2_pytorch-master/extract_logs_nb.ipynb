# %%
'''
FORMAT OF ACCURACY DICTIONARY
training size : [[train accuracy, test accuracy, class accuracy], ... ]

key: training size (40, 120, etc.)
value: array of 100 arrays (one for each epoch)

'''
acc = {}
ind = -1
sizes = [40, 240, 320, 400, 600]
test_size = [40]
for size in sizes:
    with open (f'/Users/oorjamajgaonkar/Documents/capstone/Pointnet_Pointnet2_pytorch/log/logfile-{size}-balanced.txt', 'r') as f:
        for line in f:
            if line.find("Epoch") != -1:
                epoch = int(line.split(" ")[-2]) # epoch number
                #ind += 1
            elif line.find("Train Instance Accuracy") != -1:
                arr = [float(line.split(": ")[1])]
            elif line.find("Test Instance Accuracy") != -1:
                arr.append(float(line.split(" ")[-4].strip(","))) # overall test accuracy
                arr.append(float(line.split(" ")[-1])) # class accuracy
                if size in acc:
                    acc[size].append(arr)
                else:
                    acc[size] = []
                    acc[size].append(arr)

# %%
import matplotlib.pyplot as plt

# %%
acc
# Out:
# [0.02451,
#  0.281863,
#  0.404412,
#  0.464461,
#  0.425245,
#  0.38848,
#  0.493873,
#  0.529412,
#  0.490196,
#  0.557598,
#  0.519608,
#  0.598039,
#  0.473039,
#  0.556373,
#  0.574755,
#  0.610294,
#  0.594363,
#  0.522059,
#  0.594363,
#  0.632353,
#  0.653186,
#  0.64951,
#  0.627451,
#  0.669118,
#  0.660539,
#  0.623775,
#  0.670343,
#  0.693627,
#  0.661765,
#  0.63848,
#  0.686275,
#  0.683824,
#  0.693627,
#  0.698529,
#  0.626225,
#  0.665441,
#  0.642157,
#  0.715686,
#  0.691176,
#  0.659314,
#  0.670343,
#  0.719363,
#  0.756127,
#  0.705882,
#  0.726716,
#  0.75,
#  0.740196,
#  0.704657,
#  0.732843,
#  0.710784,
#  0.713235,
#  0.732843,
#  0.726716,
#  0.723039,
#  0.683824,
#  0.719363,
#  0.681373,
#  0.727941,
#  0.721814,
#  0.753676,
#  0.754902,
#  0.743873,
#  0.756127,
#  0.775735,
#  0.730392,
#  0.740196,
#  0.72549,
#  0.742647,
#  0.769608,
#  0.738971,
#  0.765931,
#  0.76348,
#  0.703431,
#  0.724265,
#  0.714461,
#  0.73652,
#  0.762255,
#  0.745098,
#  0.751225,
#  0.73652,
#  0.743873,
#  0.778186,
#  0.753676,
#  0.767157,
#  0.791667,
#  0.756127,
#  0.76348,
#  0.748775,
#  0.768382,
#  0.72549,
#  0.753676,
#  0.758578,
#  0.741422,
#  0.740196,
#  0.756127,
#  0.754902,
#  0.757353,
#  0.756127,
#  0.759804,
#  0.759804]

# %%
acc_array = []
for size in sizes:
    acc_array.append([a[1] for a in acc[size]])
#test_acc_40 = [a[1] for a in acc[40]]
#test_acc_120 = [a[1] for a in acc[120]]

# %%
xvals = []
for size in sizes:
    xvals.append([size * i for i in range(1, 101)])
for acc in acc_array:
    print(len(acc))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
ind = 0
for arr in acc_array:
    plt.plot(xvals[ind], arr, label = str(sizes[ind]))
    ind += 1
plt.figure(num=1, figsize=(20, 10))
plt.legend()
plt.axis([0, 10000, 0, 0.7])
plt.show()

# %%
plt.plot(test_acc_40, label = "40")
plt.plot(test_acc_120, label = "120")
plt.show()

# %%
plt.show()

# %%
plt120.plot(test_acc_120, label = "120")
